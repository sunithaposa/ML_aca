# %%
import re # for regular expressions
import pandas as pd 
pd.set_option("display.max_colwidth", 200)
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import string
import nltk # for text manipulation
import warnings 
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %matplotlib inline

# %%
train  = pd.read_csv('C:\\Users\\Lenovo\\ML\\NLP\\train_E6oV3lV.csv')
test = pd.read_csv('C:\\Users\\Lenovo\\ML\\NLP\\test_tweets_anuFYb8.csv')
train.head()
# Out:
#    id  label  \
# 0   1      0
# 1   2      0
# 2   3      0
# 3   4      0
# 4   5      0
#
#                                                                                                                         tweet
# 0                       @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1  @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                                         bihday your majesty
# 3                                      #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# 4                                                                                      factsguide: society now    #motivation

# %%
train.shape, test.shape
# Out:
# ((31962, 3), (17197, 2))

# %%
train["label"].value_counts()
# Out:
# 0    29720
# 1     2242
# Name: label, dtype: int64

# %%
combi = train.append(test, ignore_index=True)
print(combi.shape)
combi.head()
# Out:
# (49159, 3)
#    id  label  \
# 0   1    0.0
# 1   2    0.0
# 2   3    0.0
# 3   4    0.0
# 4   5    0.0
#
#                                                                                                                         tweet
# 0                       @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1  @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                                         bihday your majesty
# 3                                      #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# 4                                                                                      factsguide: society now    #motivation

# %%
def remove_pattern(input_txt, pattern):
    r = re.findall(pattern, input_txt)
    for i in r:
        input_txt = re.sub(i, '', input_txt)
        
    return input_txt

# %%
combi['tidy_tweet'] = np.vectorize(remove_pattern)(combi['tweet'], "@[\w]*") 
combi.head()
# Out:
#    id  label  \
# 0   1    0.0
# 1   2    0.0
# 2   3    0.0
# 3   4    0.0
# 4   5    0.0
#
#                                                                                                                         tweet  \
# 0                       @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1  @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                                         bihday your majesty
# 3                                      #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# 4                                                                                      factsguide: society now    #motivation
#
#                                                                                                          tidy_tweet
# 0                   when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1    thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                               bihday your majesty
# 3                            #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# 4                                                                            factsguide: society now    #motivation

# %%
combi['tidy_tweet'] = combi['tidy_tweet'].str.replace("[^a-zA-Z#]", " ")
combi.head(10)
# Out:
#    id  label  \
# 0   1    0.0
# 1   2    0.0
# 2   3    0.0
# 3   4    0.0
# 4   5    0.0
# 5   6    0.0
# 6   7    0.0
# 7   8    0.0
# 8   9    0.0
# 9  10    0.0
#
#                                                                                                                                              tweet  \
# 0                                            @user when a father is dysfunctional and is so selfish he drags his kids into his dysfunction.   #run
# 1                       @user @user thanks for #lyft credit i can't use cause they don't offer wheelchair vans in pdx.    #disapointed #getthanked
# 2                                                                                                                              bihday your majesty
# 3                                                           #model   i love u take with u all the time in urð±!!! ðððð
# ð¦ð¦ð¦
# 4                                                                                                           factsguide: society now    #motivation
# 5                             [2/2] huge fan fare and big talking before they leave. chaos and pay disputes when they get there. #allshowandnogo
# 6                                                                        @user camping tomorrow @user @user @user @user @user @user @user dannyâ¦
# 7  the next school year is the year for exams.ð¯ can't think about that ð­ #school #exams   #hate #imagine #actorslife #revolutionschool #girl
# 8                                                          we won!!! love the land!!! #allin #cavs #champions #cleveland #clevelandcavaliers  â¦
# 9                                                                                                @user @user welcome here !  i'm   it's so #gr8 !
#
#                                                                                                                                         tidy_tweet
# 0                                                  when a father is dysfunctional and is so selfish he drags his kids into his dysfunction    #run
# 1                                   thanks for #lyft credit i can t use cause they don t offer wheelchair vans in pdx     #disapointed #getthanked
# 2                                                                                                                              bihday your majesty
# 3                                                           #model   i love u take with u all the time in ur
# 4                                                                                                           factsguide  society now    #motivation
# 5                                   huge fan fare and big talking before they leave  chaos and pay disputes when they get there  #allshowandnogo
# 6                                                                                                                 camping tomorrow        danny
# 7  the next school year is the year for exams      can t think about that      #school #exams   #hate #imagine #actorslife #revolutionschool #girl
# 8                                                          we won    love the land    #allin #cavs #champions #cleveland #clevelandcavaliers
# 9                                                                                                            welcome here    i m   it s so #gr

# %%
combi['tidy_tweet'] = combi['tidy_tweet'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>3]))

# %%
tokenized_tweet = combi['tidy_tweet'].apply(lambda x: x.split()) # tokenizing

# %%
from nltk.stem.porter import *
stemmer = PorterStemmer()

tokenized_tweet = tokenized_tweet.apply(lambda x: [stemmer.stem(i) for i in x]) # stemming
tokenized_tweet
# Out:
# 0                                                                [when, father, dysfunct, selfish, drag, kid, into, dysfunct, #run]
# 1                                                 [thank, #lyft, credit, caus, they, offer, wheelchair, van, #disapoint, #getthank]
# 2                                                                                                           [bihday, your, majesti]
# 3                                                                                                  [#model, love, take, with, time]
# 4                                                                                                      [factsguid, societi, #motiv]
# 5                                           [huge, fare, talk, befor, they, leav, chao, disput, when, they, there, #allshowandnogo]
# 6                                                                                                           [camp, tomorrow, danni]
# 7        [next, school, year, year, exam, think, about, that, #school, #exam, #hate, #imagin, #actorslif, #revolutionschool, #girl]
# 8                                                               [love, land, #allin, #cav, #champion, #cleveland, #clevelandcavali]
# 9                                                                                                                    [welcom, here]
# 10                                            [#ireland, consum, price, index, climb, from, previou, #blog, #silver, #gold, #forex]
# 11            [selfish, #orlando, #standwithorlando, #pulseshoot, #orlandoshoot, #biggerproblem, #selfish, #heabreak, #valu, #love]
# 12                                                                                                   [daddi, today, day, #gettingf]
# 13                                                                [#cnn, call, #michigan, middl, school, build, wall, chant, #tcot]
# 14                                  [comment, #australia, #opkillingbay, #seashepherd, #helpcovedolphin, #thecov, #helpcovedolphin]
# 15                                                                             [ouch, junior, angri, #got, #junior, #yugyoem, #omg]
# 16                                                                                             [thank, have, paner, #thank, #posit]
# 17                                                                                                                  [retweet, agre]
# 18                                                                              [#friday, smile, around, user, #cooki, make, peopl]
# 19                                                                                               [know, essenti, oil, made, chemic]
# 20                               [#euro, peopl, blame, conced, goal, rooney, gave, away, free, kick, know, bale, them, from, there]
# 21                                                                 [littl, dude, #badday, #coneofsham, #cat, #piss, #funni, #laugh]
# 22                                                                       [product, happi, #wine, tool, #weekend, time, open, drink]
# 23                                                                                                       [lumpi, say, prove, lumpi]
# 24                                                                              [#tgif, #gamedev, #indiedev, #indiegamedev, #squad]
# 25                                                                     [beauti, sign, vendor, #upsideofflorida, #shopalyssa, #love]
# 26                                                [#smile, when, #media, #pressconfer, #antalya, #turkey, sunday, #throwback, love]
# 27                                                                                     [great, panel, mediat, public, servic, #ica]
# 28                                                                                                                  [happi, father]
# 29                [peopl, went, nightclub, have, good, night, action, mean, those, peopl, lost, their, famili, forev, #rip#orlando]
#                                                                     ...
# 49129                                                                                         [peopl, anyth, fuck, attent, nowaday]
# 49130                                                     [creativ, bubbl, burst, look, forward, never, have, colleg, tutor, again]
# 49131                                                              [tomorrow, gonna, go, deliv, first, book, abroad, #donat, #book]
# 49132                                                                                          [thank, babi, giggl, #thank, #posit]
# 49133                                                                                              [#model, love, take, with, time]
# 49134                          [life, will, grow, learn, some, pple, will, work, fuck, over, just, life, look, feel, better, there]
# 49135                                                  [storm, were, rain, togeth, destroy, thi, town, becam, name, #myquot, #love]
# 49136                    [lovelgq, broken, #rnb, #love, #heabroken, #hea, #drake, #music, #studio, #worldstar, #billboard, #mixtap]
# 49137                                                        [spread, love, hate, #prayingfororlando, #loveanoth, #tragic, #prayer]
# 49138                                                                                                          [most, racist, ever]
# 49139                                                                                             [thank, children, #thank, #posit]
# 49140                                             [liverpool, #walk, #liverpool, #starbuck, #avidaeboa, #passeio, #chocol, #delici]
# 49141                                            [#bakersfield, rooster, simul, want, climb, vast, expans, mountain, reach, leakag]
# 49142                                        [#instagood, #beauti, #instadaili, #instalik, #instamood, #amaz, #bestoftheday, #cool]
# 49143                                                [hell, yeah, what, great, surpris, your, present, enjoy, thi, pictur, #bihday]
# 49144                                                                                         [when, joke, defens, toward, everyth]
# 49145                                                         [#enjoy, #even, #sun, #bedroom, #cozi, even, #homesweethom, #allwhit]
# 49146                                                         [tonight, from, here, special, earli, play, song, from, upcom, album]
# 49147                                              [today, good, excercis, #imreadi, #sofuckenreadi, #letsgo, #comeon, #letsgetsta]
# 49148                                           [good, night, with, music, #billi, #music, #tea, #mug, #tokiohotelmug, #tokiohotel]
# 49149                                               [love, life, #createyourfutur, #lifestyl, #holiday, hyatt, regenc, long, beach]
# 49150                                  [black, professor, demon, propos, nazi, style, confisc, white, asset, like, germani, #break]
# 49151                                                                         [learn, think, posit, #posit, #instagram, #instagood]
# 49152                                        [love, pretti, happi, fresh, #teenilici, #fixdermateen, #generationz, #pretti, #fresh]
# 49153                                                            [damn, tuff, ruff, muff, techno, citi, ukhx, #web, hardcor, gabba]
# 49154                                [thought, factori, left, right, polaris, #trump, #uselect, #leadership, #polit, #brexit, #blm]
# 49155                                         [feel, like, mermaid, #hairflip, #neverreadi, #formal, #wed, #gown, #dress, #mermaid]
# 49156                 [#hillari, #campaign, today, #ohio, use, word, like, asset, liabil, never, onc, #clinton, thee, word, #radic]
# 49157                                          [happi, work, confer, right, mindset, lead, cultur, develop, organ, #work, #mindset]
# 49158                                                                     [song, glad, free, download, #shoegaz, #newmus, #newsong]
# Name: tidy_tweet, Length: 49159, dtype: object

# %%
for i in range(len(tokenized_tweet)):
    tokenized_tweet[i] = ' '.join(tokenized_tweet[i])
    
combi['tidy_tweet'] = tokenized_tweet
combi['tidy_tweet']
# Out:
# 0                                                          when father dysfunct selfish drag kid into dysfunct #run
# 1                                            thank #lyft credit caus they offer wheelchair van #disapoint #getthank
# 2                                                                                               bihday your majesti
# 3                                                                                        #model love take with time
# 4                                                                                          factsguid societi #motiv
# 5                                        huge fare talk befor they leav chao disput when they there #allshowandnogo
# 6                                                                                               camp tomorrow danni
# 7        next school year year exam think about that #school #exam #hate #imagin #actorslif #revolutionschool #girl
# 8                                                       love land #allin #cav #champion #cleveland #clevelandcavali
# 9                                                                                                       welcom here
# 10                                        #ireland consum price index climb from previou #blog #silver #gold #forex
# 11       selfish #orlando #standwithorlando #pulseshoot #orlandoshoot #biggerproblem #selfish #heabreak #valu #love
# 12                                                                                        daddi today day #gettingf
# 13                                                          #cnn call #michigan middl school build wall chant #tcot
# 14                          comment #australia #opkillingbay #seashepherd #helpcovedolphin #thecov #helpcovedolphin
# 15                                                                     ouch junior angri #got #junior #yugyoem #omg
# 16                                                                                   thank have paner #thank #posit
# 17                                                                                                     retweet agre
# 18                                                                      #friday smile around user #cooki make peopl
# 19                                                                                     know essenti oil made chemic
# 20                               #euro peopl blame conced goal rooney gave away free kick know bale them from there
# 21                                                          littl dude #badday #coneofsham #cat #piss #funni #laugh
# 22                                                                product happi #wine tool #weekend time open drink
# 23                                                                                            lumpi say prove lumpi
# 24                                                                    #tgif #gamedev #indiedev #indiegamedev #squad
# 25                                                            beauti sign vendor #upsideofflorida #shopalyssa #love
# 26                                          #smile when #media #pressconfer #antalya #turkey sunday #throwback love
# 27                                                                            great panel mediat public servic #ica
# 28                                                                                                     happi father
# 29                peopl went nightclub have good night action mean those peopl lost their famili forev #rip#orlando
#                                                             ...
# 49129                                                                               peopl anyth fuck attent nowaday
# 49130                                                creativ bubbl burst look forward never have colleg tutor again
# 49131                                                        tomorrow gonna go deliv first book abroad #donat #book
# 49132                                                                                thank babi giggl #thank #posit
# 49133                                                                                    #model love take with time
# 49134                           life will grow learn some pple will work fuck over just life look feel better there
# 49135                                              storm were rain togeth destroy thi town becam name #myquot #love
# 49136                 lovelgq broken #rnb #love #heabroken #hea #drake #music #studio #worldstar #billboard #mixtap
# 49137                                                spread love hate #prayingfororlando #loveanoth #tragic #prayer
# 49138                                                                                              most racist ever
# 49139                                                                                  thank children #thank #posit
# 49140                                      liverpool #walk #liverpool #starbuck #avidaeboa #passeio #chocol #delici
# 49141                                       #bakersfield rooster simul want climb vast expans mountain reach leakag
# 49142                                 #instagood #beauti #instadaili #instalik #instamood #amaz #bestoftheday #cool
# 49143                                            hell yeah what great surpris your present enjoy thi pictur #bihday
# 49144                                                                               when joke defens toward everyth
# 49145                                                  #enjoy #even #sun #bedroom #cozi even #homesweethom #allwhit
# 49146                                                    tonight from here special earli play song from upcom album
# 49147                                       today good excercis #imreadi #sofuckenreadi #letsgo #comeon #letsgetsta
# 49148                                      good night with music #billi #music #tea #mug #tokiohotelmug #tokiohotel
# 49149                                         love life #createyourfutur #lifestyl #holiday hyatt regenc long beach
# 49150                               black professor demon propos nazi style confisc white asset like germani #break
# 49151                                                                learn think posit #posit #instagram #instagood
# 49152                                  love pretti happi fresh #teenilici #fixdermateen #generationz #pretti #fresh
# 49153                                                       damn tuff ruff muff techno citi ukhx #web hardcor gabba
# 49154                            thought factori left right polaris #trump #uselect #leadership #polit #brexit #blm
# 49155                                    feel like mermaid #hairflip #neverreadi #formal #wed #gown #dress #mermaid
# 49156                 #hillari #campaign today #ohio use word like asset liabil never onc #clinton thee word #radic
# 49157                                      happi work confer right mindset lead cultur develop organ #work #mindset
# 49158                                                             song glad free download #shoegaz #newmus #newsong
# Name: tidy_tweet, Length: 49159, dtype: object

# %%
all_words = ' '.join([text for text in combi['tidy_tweet']])
from wordcloud import WordCloud
wordcloud = WordCloud(width=1200, height=800, random_state=21, max_font_size=110).generate(all_words)

plt.figure(figsize=(30, 20))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-b0c6b4209692> in <module>
#       1 all_words = ' '.join([text for text in combi['tidy_tweet']])
# ----> 2 from wordcloud import WordCloud
#       3 wordcloud = WordCloud(width=1200, height=800, random_state=21, max_font_size=110).generate(all_words)
#       4
#       5 plt.figure(figsize=(30, 20))
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
# function to collect hashtags
def hashtag_extract(x):
    hashtags = []
    # Loop over the words in the tweet
    for i in x:
        ht = re.findall(r"#(\w+)", i)
        hashtags.append(ht)

    return hashtags

# %%
# extracting hashtags from non racist/sexist tweets

HT_regular = hashtag_extract(combi['tidy_tweet'][combi['label'] == 0])

# extracting hashtags from racist/sexist tweets
HT_negative = hashtag_extract(combi['tidy_tweet'][combi['label'] == 1])

# unnesting list
HT_regular = sum(HT_regular,[])
HT_negative = sum(HT_negative,[])
print(HT_regular)
print(HT_negative)
# Out:
# ['run', 'lyft', 'disapoint', 'getthank', 'model', 'motiv', 'allshowandnogo', 'school', 'exam', 'hate', 'imagin', 'actorslif', 'revolutionschool', 'girl', 'allin', 'cav', 'champion', 'cleveland', 'clevelandcavali', 'ireland', 'blog', 'silver', 'gold', 'forex', 'orlando', 'standwithorlando', 'pulseshoot', 'orlandoshoot', 'biggerproblem', 'selfish', 'heabreak', 'valu', 'love', 'gettingf', 'got', 'junior', 'yugyoem', 'omg', 'thank', 'posit', 'friday', 'cooki', 'euro', 'badday', 'coneofsham', 'cat', 'piss', 'funni', 'laugh', 'wine', 'weekend', 'tgif', 'gamedev', 'indiedev', 'indiegamedev', 'squad', 'upsideofflorida', 'shopalyssa', 'love', 'smile', 'media', 'pressconfer', 'antalya', 'turkey', 'throwback', 'ica', 'rip', 'orlando', 'alohafriday', 'time', 'not', 'exist', 'positivevib', 'hawaiian', 'goodnight', 'badmonday', 'taylorswift', 'travelingram', 'dalat', 'ripinkylif', 'photoshop', 'enoughisenough', 'dontphotoshopeveryth', 'wheresallthenaturalphoto', 'cedarpoint', 'thank', 'posit', 'bookworm', 'ontothenextnovel', 'flow', 'grow', 'garden', 'iphonesia', 'bliss', 'bloom', 'basilicabotanica', 'posit', 'affirm', 'model', 'whenev', 'someth', 'wrong', 'illustr', 'abc', 'pulseclub', 'prayfororlando', 'bihday', 'nose', 'job', 'bihday', 'petunia', 'albanpilgrimag', 'wedding', 'video', 'father', 'day', 'rayo', 'world', 'hotvideo', 'video', 'ascot', 'fashion', 'monochrom', 'style', 'instahappyday', 'selfi', 'yolo', 'xoxo', 'like', 'work', 'mindset', 'christinarip', 'voic', 'christinagrimmi', 'roar', 'preschool', 'student', 'proud', 'chatiado', 'travel', 'yeah', 'thejourneybegin', 'hello', 'luv', 'hottweet', 'venusexchang', 'awork', 'solut', 'orlando', 'disneygatorattack', 'proud', 'udtapunjab', 'amarind', 'aap', 'senseaboutmath', 'golfstrengthandcondit', 'strong', 'felixfoisgolf', 'greathonour', 'careerconvo', 'innov', 'wateringhol', 'cave', 'mountaintop', 'campfir', 'heal', 'altwaystoh', 'healthi', 'peac', 'midweek', 'newmus', 'watchthisspac', 'guitar', 'snapchat', 'redhead', 'vermillionr', 'peopl', 'goodtim', 'histori', 'summeim', 'memori', 'memori', 'model', 'hump', 'hump', 'humper', 'shop', 'cool', 'home', 'fun', 'nashvilletour', 'nashvilleforev', 'eur', 'blog', 'silver', 'gold', 'forex', 'thank', 'posit', 'christinagrimmi', 'prayfororlando', 'eyelid
', 'canuck', 'oiler', 'american', 'bigotri', 'hatr', 'homophob', 'warmong', 'worlddang', 'trumpsamerica', 'hate', 'america', 'controversi', 'equal', 'kaepernick', 'nationalanthem', 'laurenduca', 'hispan', 'black', 'asian', 'cnn', 'hispan', 'retweet', 'boricua', 'miami', 'hatr', 'xenophobia', 'islamophobia', 'antisemit', 'war', 'antirac', 'seashepherd', 'polit', 'relationship', 'new', 'santa', 'obama', 'soro', 'allahsoi ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import gensim
train['tweet'].head(10)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-944de6ceba48> in <module>
#       1 from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
# ----> 2 import gensim
#       3 train['tweet'].head(10)
#
# ModuleNotFoundError: No module named 'gensim'

# %%
bow_vectorizer = CountVectorizer(max_df=0.90, min_df=2, max_features=1000, stop_words='english')
bow = bow_vectorizer.fit_transform(combi['tidy_tweet'])
print(bow.shape)
print(bow)
# Out:
# (49159, 1000)
#   (0, 738)	1
#   (0, 463)	1
#   (0, 302)	1
#   (1, 600)	1
#   (1, 131)	1
#   (1, 879)	1
#   (2, 79)	1
#   (3, 888)	1
#   (3, 518)	1
#   (3, 557)	1
#   (4, 566)	1
#   (5, 485)	1
#   (5, 69)	1
#   (5, 858)	1
#   (5, 423)	1
#   (6, 894)	1
#   (6, 121)	1
#   (7, 353)	1
#   (7, 432)	1
#   (7, 393)	1
#   (7, 883)	1
#   (7, 283)	2
#   (7, 992)	2
#   (7, 749)	2
#   (8, 132)	1
#   :	:
#   (49154, 728)	1
#   (49155, 246)	1
#   (49155, 961)	1
#   (49155, 307)	1
#   (49155, 498)	1
#   (49156, 122)	1
#   (49156, 411)	1
#   (49156, 929)	1
#   (49156, 980)	2
#   (49156, 605)	1
#   (49156, 498)	1
#   (49156, 891)	1
#   (49157, 612)	1
#   (49157, 226)	1
#   (49157, 198)	1
#   (49157, 480)	1
#   (49157, 553)	2
#   (49157, 728)	1
#   (49157, 175)	1
#   (49157, 981)	2
#   (49157, 389)	1
#   (49158, 356)	1
#   (49158, 243)	1
#   (49158, 799)	1
#   (49158, 333)	1

# %%
tfidf_vectorizer = TfidfVectorizer(max_df=0.90, min_df=.0, max_features=1000, stop_words='english')
tfidf = tfidf_vectorizer.fit_transform(combi['tidy_tweet'])
tfidf.shape
print(tfidf)

i am traveling to blr and i am going to join a comapny  -1
i am going to office  - 2 


TF  = number of the times key appear into a documents /total number of a key availble into a documnet 
    = 2/13

IDF =log (total number of document /the numbrer of document with this key )
    = log(2/2)
    = log(1) = 0 
    
    TF*IDF = 0
# Out:
#   File "<ipython-input-21-644f1d5ed5c9>", line 6
#     i am traveling to blr and i am going to join a comapny  -1
#        ^
# SyntaxError: invalid syntax

# %%
train_bow = bow[:31962,:]
test_bow = bow[31962:,:]

from sklearn.model_selection import train_test_split
# splitting data into training and validation set
xtrain_bow, xvalid_bow, ytrain, yvalid = train_test_split(train_bow, train['label'],  
                                                          random_state=42, 
                                                          test_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score
lreg = LogisticRegression()
lreg.fit(xtrain_bow, ytrain) # training the model

prediction = lreg.predict_proba(xvalid_bow) # predicting on the validation set
prediction_int = prediction[:,1] >= 0.3 # if prediction is greater than or equal to 0.3 than 1 else 0
prediction_int = prediction_int.astype(np.int)

f1_score(yvalid, prediction_int) # calculating f1 score
# Out:
# 0.5307820299500832
